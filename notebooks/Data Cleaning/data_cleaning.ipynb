# %% [markdown]
# # NYC Yellow Taxi Data - Comprehensive Data Cleaning
# ## Removing Invalid Records Across All Years
#
# This notebook removes:
# - Zero and negative trip distances
# - Negative fares
# - Other data quality issues
#
# **Output**: Cleaned parquet files in `data/processed/`

# %%
# Import required libraries
import pandas as pd
import numpy as np
import os
from glob import glob
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

print("=" * 80)
print("NYC YELLOW TAXI DATA - COMPREHENSIVE CLEANING PIPELINE")
print("=" * 80)
print(f"Start Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ================================================================================
# NYC YELLOW TAXI DATA - COMPREHENSIVE CLEANING PIPELINE
# ================================================================================
# Start Time: 2025-10-06 21:47:25

# %%
# Configuration
RAW_DATA_PATH = '/Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/raw/'
PROCESSED_DATA_PATH = '/Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/'

# Create output directory
os.makedirs(PROCESSED_DATA_PATH, exist_ok=True)

# Find all parquet files
all_files = []
for year in ['2022', '2023', '2024', '2025']:
    year_path = os.path.join(RAW_DATA_PATH, year)
    if os.path.exists(year_path):
        files = glob(os.path.join(year_path, '*.parquet'))
        all_files.extend(files)

print(f"\n📁 Found {len(all_files)} parquet files to process")
print(f"📂 Output directory: {PROCESSED_DATA_PATH}")
# Out:
# 📁 Found 44 parquet files to process
# 📂 Output directory: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/

# %%
# Define cleaning function
def clean_taxi_data(df):
    """
    Apply all data cleaning rules to a DataFrame
    
    Returns: cleaned_df, cleaning_stats
    """
    initial_count = len(df)
    stats = {}
    
    # 1. Remove zero and negative trip distances
    zero_distance = (df['trip_distance'] <= 0).sum()
    df = df[df['trip_distance'] > 0]
    stats['zero_negative_distance'] = zero_distance
    
    # 2. Remove negative fares
    negative_fare = (df['fare_amount'] < 0).sum()
    df = df[df['fare_amount'] >= 0]
    stats['negative_fare'] = negative_fare
    
    # 3. Remove zero fares (likely errors or no-charges that shouldn't be analyzed)
    zero_fare = (df['fare_amount'] == 0).sum()
    df = df[df['fare_amount'] > 0]
    stats['zero_fare'] = zero_fare
    
    # 4. Remove zero or negative passenger counts
    invalid_passengers = (df['passenger_count'] <= 0).sum()
    df = df[df['passenger_count'] > 0]
    stats['invalid_passengers'] = invalid_passengers
    
    # 5. Remove trips with negative duration
    df['trip_duration_minutes'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
    negative_duration = (df['trip_duration_minutes'] <= 0).sum()
    df = df[df['trip_duration_minutes'] > 0]
    stats['negative_duration'] = negative_duration
    
    # 6. Remove extreme outliers (likely data entry errors)
    extreme_fare = (df['fare_amount'] > 1000).sum()
    df = df[df['fare_amount'] <= 1000]
    stats['extreme_fare'] = extreme_fare
    
    extreme_distance = (df['trip_distance'] > 200).sum()
    df = df[df['trip_distance'] <= 200]
    stats['extreme_distance'] = extreme_distance
    
    extreme_duration = (df['trip_duration_minutes'] > 300).sum()  # 5 hours
    df = df[df['trip_duration_minutes'] <= 300]
    stats['extreme_duration'] = extreme_duration
    
    # 7. Remove duplicate records
    duplicates = df.duplicated().sum()
    df = df.drop_duplicates()
    stats['duplicates'] = duplicates
    
    # Calculate cleaning summary
    stats['initial_count'] = initial_count
    stats['final_count'] = len(df)
    stats['total_removed'] = initial_count - len(df)
    stats['removal_percentage'] = (stats['total_removed'] / initial_count * 100) if initial_count > 0 else 0
    
    # Drop temporary columns
    if 'trip_duration_minutes' in df.columns:
        df = df.drop(columns=['trip_duration_minutes'])
    
    return df, stats

print("✅ Cleaning function defined")
# Out:
# ✅ Cleaning function defined

# %%
# Process all files
print("\n" + "=" * 80)
print("🧹 PROCESSING FILES")
print("=" * 80)

overall_stats = {
    'files_processed': 0,
    'total_initial_records': 0,
    'total_final_records': 0,
    'total_removed_records': 0,
    'zero_negative_distance': 0,
    'negative_fare': 0,
    'zero_fare': 0,
    'invalid_passengers': 0,
    'negative_duration': 0,
    'extreme_fare': 0,
    'extreme_distance': 0,
    'extreme_duration': 0,
    'duplicates': 0
}

for i, file_path in enumerate(sorted(all_files), 1):
    try:
        # Extract year and filename
        year = file_path.split('/')[-2]
        filename = os.path.basename(file_path)
        
        print(f"\n[{i}/{len(all_files)}] Processing: {year}/{filename}")
        
        # Load data
        df = pd.read_parquet(file_path)
        initial_size = len(df)
        
        # Clean data
        df_clean, stats = clean_taxi_data(df)
        
        # Create output directory for year
        year_output_path = os.path.join(PROCESSED_DATA_PATH, year)
        os.makedirs(year_output_path, exist_ok=True)
        
        # Save cleaned data
        output_file = os.path.join(year_output_path, filename)
        df_clean.to_parquet(output_file, index=False)
        
        # Update overall stats
        overall_stats['files_processed'] += 1
        overall_stats['total_initial_records'] += stats['initial_count']
        overall_stats['total_final_records'] += stats['final_count']
        overall_stats['total_removed_records'] += stats['total_removed']
        
        for key in ['zero_negative_distance', 'negative_fare', 'zero_fare', 'invalid_passengers',
                    'negative_duration', 'extreme_fare', 'extreme_distance', 'extreme_duration', 'duplicates']:
            overall_stats[key] += stats[key]
        
        # Print file summary
        print(f"  Initial: {stats['initial_count']:,} | Final: {stats['final_count']:,} | Removed: {stats['total_removed']:,} ({stats['removal_percentage']:.2f}%)")
        print(f"  ✅ Saved to: {output_file}")
        
    except Exception as e:
        print(f"  ❌ Error processing {filename}: {str(e)}")
        continue

print("\n" + "=" * 80)
print("✅ ALL FILES PROCESSED")
print("=" * 80)
# Out:
# ================================================================================
# 🧹 PROCESSING FILES
# ================================================================================
#
# [1/44] Processing: 2022/yellow_tripdata_2022-01.parquet
#   Initial: 2,463,931 | Final: 2,299,197 | Removed: 164,734 (6.69%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-01.parquet
#
# [2/44] Processing: 2022/yellow_tripdata_2022-02.parquet
#   Initial: 2,979,431 | Final: 2,768,518 | Removed: 210,913 (7.08%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-02.parquet
#
# [3/44] Processing: 2022/yellow_tripdata_2022-03.parquet
#   Initial: 3,627,882 | Final: 3,376,555 | Removed: 251,327 (6.93%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-03.parquet
#
# [4/44] Processing: 2022/yellow_tripdata_2022-04.parquet
#   Initial: 3,599,920 | Final: 3,348,837 | Removed: 251,083 (6.97%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-04.parquet
#
# [5/44] Processing: 2022/yellow_tripdata_2022-05.parquet
#   Initial: 3,588,295 | Final: 3,319,384 | Removed: 268,911 (7.49%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-05.parquet
#
# [6/44] Processing: 2022/yellow_tripdata_2022-06.parquet
#   Initial: 3,558,124 | Final: 3,285,701 | Removed: 272,423 (7.66%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-06.parquet
#
# [7/44] Processing: 2022/yellow_tripdata_2022-07.parquet
#   Initial: 3,174,394 | Final: 2,942,945 | Removed: 231,449 (7.29%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-07.parquet
#
# [8/44] Processing: 2022/yellow_tripdata_2022-08.parquet
#   Initial: 3,152,677 | Final: 2,934,038 | Removed: 218,639 (6.94%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-08.parquet
#
# [9/44] Processing: 2022/yellow_tripdata_2022-09.parquet
#   Initial: 3,183,767 | Final: 2,941,661 | Removed: 242,106 (7.60%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-09.parquet
#
# [10/44] Processing: 2022/yellow_tripdata_2022-10.parquet
#   Initial: 3,675,411 | Final: 3,395,481 | Removed: 279,930 (7.62%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-10.parquet
#
# [11/44] Processing: 2022/yellow_tripdata_2022-11.parquet
#   Initial: 3,252,717 | Final: 3,014,945 | Removed: 237,772 (7.31%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-11.parquet
#
# [12/44] Processing: 2022/yellow_tripdata_2022-12.parquet
#   Initial: 3,399,549 | Final: 3,137,268 | Removed: 262,281 (7.72%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2022/yellow_tripdata_2022-12.parquet
#
# [13/44] Processing: 2023/yellow_tripdata_2023-01.parquet
#   Initial: 3,066,766 | Final: 2,881,314 | Removed: 185,452 (6.05%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-01.parquet
#
# [14/44] Processing: 2023/yellow_tripdata_2023-02.parquet
#   Initial: 2,913,955 | Final: 2,729,840 | Removed: 184,115 (6.32%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-02.parquet
#
# [15/44] Processing: 2023/yellow_tripdata_2023-03.parquet
#   Initial: 3,403,766 | Final: 3,187,276 | Removed: 216,490 (6.36%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-03.parquet
#
# [16/44] Processing: 2023/yellow_tripdata_2023-04.parquet
#   Initial: 3,288,250 | Final: 3,074,502 | Removed: 213,748 (6.50%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-04.parquet
#
# [17/44] Processing: 2023/yellow_tripdata_2023-05.parquet
#   Initial: 3,513,649 | Final: 3,278,505 | Removed: 235,144 (6.69%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-05.parquet
#
# [18/44] Processing: 2023/yellow_tripdata_2023-06.parquet
#   Initial: 3,307,234 | Final: 3,081,946 | Removed: 225,288 (6.81%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-06.parquet
#
# [19/44] Processing: 2023/yellow_tripdata_2023-07.parquet
#   Initial: 2,907,108 | Final: 2,710,324 | Removed: 196,784 (6.77%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-07.parquet
#
# [20/44] Processing: 2023/yellow_tripdata_2023-08.parquet
#   Initial: 2,824,209 | Final: 2,626,390 | Removed: 197,819 (7.00%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-08.parquet
#
# [21/44] Processing: 2023/yellow_tripdata_2023-09.parquet
#   Initial: 2,846,722 | Final: 2,602,739 | Removed: 243,983 (8.57%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-09.parquet
#
# [22/44] Processing: 2023/yellow_tripdata_2023-10.parquet
#   Initial: 3,522,285 | Final: 3,241,099 | Removed: 281,186 (7.98%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-10.parquet
#
# [23/44] Processing: 2023/yellow_tripdata_2023-11.parquet
#   Initial: 3,339,715 | Final: 3,089,287 | Removed: 250,428 (7.50%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-11.parquet
#
# [24/44] Processing: 2023/yellow_tripdata_2023-12.parquet
#   Initial: 3,376,567 | Final: 3,073,782 | Removed: 302,785 (8.97%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2023/yellow_tripdata_2023-12.parquet
#
# [25/44] Processing: 2024/yellow_tripdata_2024-01.parquet
#   Initial: 2,964,624 | Final: 2,721,958 | Removed: 242,666 (8.19%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-01.parquet
#
# [26/44] Processing: 2024/yellow_tripdata_2024-02.parquet
#   Initial: 3,007,526 | Final: 2,717,894 | Removed: 289,632 (9.63%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-02.parquet
#
# [27/44] Processing: 2024/yellow_tripdata_2024-03.parquet
#   Initial: 3,582,628 | Final: 3,034,132 | Removed: 548,496 (15.31%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-03.parquet
#
# [28/44] Processing: 2024/yellow_tripdata_2024-04.parquet
#   Initial: 3,514,289 | Final: 2,985,756 | Removed: 528,533 (15.04%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-04.parquet
#
# [29/44] Processing: 2024/yellow_tripdata_2024-05.parquet
#   Initial: 3,723,833 | Final: 3,190,718 | Removed: 533,115 (14.32%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-05.parquet
#
# [30/44] Processing: 2024/yellow_tripdata_2024-06.parquet
#   Initial: 3,539,193 | Final: 3,004,687 | Removed: 534,506 (15.10%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-06.parquet
#
# [31/44] Processing: 2024/yellow_tripdata_2024-07.parquet
#   Initial: 3,076,903 | Final: 2,681,471 | Removed: 395,432 (12.85%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-07.parquet
#
# [32/44] Processing: 2024/yellow_tripdata_2024-08.parquet
#   Initial: 2,979,183 | Final: 2,602,120 | Removed: 377,063 (12.66%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-08.parquet
#
# [33/44] Processing: 2024/yellow_tripdata_2024-09.parquet
#   Initial: 3,633,030 | Final: 3,022,906 | Removed: 610,124 (16.79%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-09.parquet
#
# [34/44] Processing: 2024/yellow_tripdata_2024-10.parquet
#   Initial: 3,833,771 | Final: 3,300,536 | Removed: 533,235 (13.91%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-10.parquet
#
# [35/44] Processing: 2024/yellow_tripdata_2024-11.parquet
#   Initial: 3,646,369 | Final: 3,144,873 | Removed: 501,496 (13.75%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-11.parquet
#
# [36/44] Processing: 2024/yellow_tripdata_2024-12.parquet
#   Initial: 3,668,371 | Final: 3,198,189 | Removed: 470,182 (12.82%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2024/yellow_tripdata_2024-12.parquet
#
# [37/44] Processing: 2025/yellow_tripdata_2025-01.parquet
#   Initial: 3,475,226 | Final: 2,814,421 | Removed: 660,805 (19.01%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-01.parquet
#
# [38/44] Processing: 2025/yellow_tripdata_2025-02.parquet
#   Initial: 3,577,543 | Final: 2,655,706 | Removed: 921,837 (25.77%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-02.parquet
#
# [39/44] Processing: 2025/yellow_tripdata_2025-03.parquet
#   Initial: 4,145,257 | Final: 3,078,157 | Removed: 1,067,100 (25.74%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-03.parquet
#
# [40/44] Processing: 2025/yellow_tripdata_2025-04.parquet
#   Initial: 3,970,553 | Final: 3,056,792 | Removed: 913,761 (23.01%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-04.parquet
#
# [41/44] Processing: 2025/yellow_tripdata_2025-05.parquet
#   Initial: 4,591,845 | Final: 3,190,706 | Removed: 1,401,139 (30.51%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-05.parquet
#
# [42/44] Processing: 2025/yellow_tripdata_2025-06.parquet
#   Initial: 4,322,960 | Final: 2,909,840 | Removed: 1,413,120 (32.69%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-06.parquet
#
# [43/44] Processing: 2025/yellow_tripdata_2025-07.parquet
#   Initial: 3,898,963 | Final: 2,673,163 | Removed: 1,225,800 (31.44%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-07.parquet
#
# [44/44] Processing: 2025/yellow_tripdata_2025-08.parquet
#   Initial: 3,574,091 | Final: 2,510,535 | Removed: 1,063,556 (29.76%)
#   ✅ Saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/2025/yellow_tripdata_2025-08.parquet
#
# ================================================================================
# ✅ ALL FILES PROCESSED
# ================================================================================

# %%
# Display overall cleaning summary
print("\n" + "=" * 80)
print("📊 OVERALL CLEANING SUMMARY")
print("=" * 80)

print(f"\n✓ Files Processed: {overall_stats['files_processed']}")
print(f"\n✓ Record Counts:")
print(f"  Initial Records:  {overall_stats['total_initial_records']:,}")
print(f"  Final Records:    {overall_stats['total_final_records']:,}")
print(f"  Removed Records:  {overall_stats['total_removed_records']:,}")
print(f"  Retention Rate:   {(overall_stats['total_final_records']/overall_stats['total_initial_records']*100):.2f}%")

print(f"\n✓ Records Removed by Category:")
print(f"  Zero/Negative Distance:  {overall_stats['zero_negative_distance']:,}")
print(f"  Negative Fare:           {overall_stats['negative_fare']:,}")
print(f"  Zero Fare:               {overall_stats['zero_fare']:,}")
print(f"  Invalid Passengers:      {overall_stats['invalid_passengers']:,}")
print(f"  Negative Duration:       {overall_stats['negative_duration']:,}")
print(f"  Extreme Fare (>$1000):   {overall_stats['extreme_fare']:,}")
print(f"  Extreme Distance (>200mi): {overall_stats['extreme_distance']:,}")
print(f"  Extreme Duration (>5hrs): {overall_stats['extreme_duration']:,}")
print(f"  Duplicates:              {overall_stats['duplicates']:,}")

print(f"\n📂 Cleaned data saved to: {PROCESSED_DATA_PATH}")
print(f"\n⏱️  Completion Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\n" + "=" * 80)
print("✅ DATA CLEANING COMPLETE - READY FOR ANALYSIS")
print("=" * 80)
# Out:
# ================================================================================
# 📊 OVERALL CLEANING SUMMARY
# ================================================================================
#
# ✓ Files Processed: 44
#
# ✓ Record Counts:
#   Initial Records:  150,692,482
#   Final Records:    130,836,094
#   Removed Records:  19,856,388
#   Retention Rate:   86.82%
#
# ✓ Records Removed by Category:
#   Zero/Negative Distance:  3,014,621
#   Negative Fare:           2,904,853
#   Zero Fare:               34,624
#   Invalid Passengers:      1,866,558
#   Negative Duration:       295,419
#   Extreme Fare (>$1000):   153
#   Extreme Distance (>200mi): 1,071
#   Extreme Duration (>5hrs): 110,031
#   Duplicates:              4
#
# 📂 Cleaned data saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/data/processed/
#
# ⏱️  Completion Time: 2025-10-06 21:54:52
#
# ================================================================================
# ✅ DATA CLEANING COMPLETE - READY FOR ANALYSIS
# ================================================================================

# %%
# Save cleaning report
report_path = '/Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/outputs/reports/'
os.makedirs(report_path, exist_ok=True)

report_file = os.path.join(report_path, f'cleaning_report_{datetime.now().strftime("%Y%m%d_%H%M%S")}.txt')

with open(report_file, 'w') as f:
    f.write("=" * 80 + "\n")
    f.write("NYC YELLOW TAXI DATA - CLEANING REPORT\n")
    f.write("=" * 80 + "\n\n")
    f.write(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
    f.write(f"Files Processed: {overall_stats['files_processed']}\n\n")
    f.write("RECORD COUNTS:\n")
    f.write(f"  Initial Records:  {overall_stats['total_initial_records']:,}\n")
    f.write(f"  Final Records:    {overall_stats['total_final_records']:,}\n")
    f.write(f"  Removed Records:  {overall_stats['total_removed_records']:,}\n")
    f.write(f"  Retention Rate:   {(overall_stats['total_final_records']/overall_stats['total_initial_records']*100):.2f}%\n\n")
    f.write("RECORDS REMOVED BY CATEGORY:\n")
    f.write(f"  Zero/Negative Distance:    {overall_stats['zero_negative_distance']:,}\n")
    f.write(f"  Negative Fare:             {overall_stats['negative_fare']:,}\n")
    f.write(f"  Zero Fare:                 {overall_stats['zero_fare']:,}\n")
    f.write(f"  Invalid Passengers:        {overall_stats['invalid_passengers']:,}\n")
    f.write(f"  Negative Duration:         {overall_stats['negative_duration']:,}\n")
    f.write(f"  Extreme Fare (>$1000):     {overall_stats['extreme_fare']:,}\n")
    f.write(f"  Extreme Distance (>200mi): {overall_stats['extreme_distance']:,}\n")
    f.write(f"  Extreme Duration (>5hrs):  {overall_stats['extreme_duration']:,}\n")
    f.write(f"  Duplicates:                {overall_stats['duplicates']:,}\n\n")
    f.write(f"Output Location: {PROCESSED_DATA_PATH}\n")
    f.write("=" * 80 + "\n")

print(f"\n📄 Cleaning report saved to: {report_file}")
# Out:
# 📄 Cleaning report saved to: /Users/yash/Documents/Projects/NYC_Yellow_Taxi_Analytics/outputs/reports/cleaning_report_20251006_215452.txt

# %%
# Quick validation - Load and verify one cleaned file
print("\n" + "=" * 80)
print("🔍 VALIDATION CHECK")
print("=" * 80)

# Get first cleaned file
cleaned_files = glob(os.path.join(PROCESSED_DATA_PATH, '**/*.parquet'), recursive=True)
if cleaned_files:
    validation_file = cleaned_files[0]
    df_validation = pd.read_parquet(validation_file)
    
    print(f"\n✓ Validating: {os.path.basename(validation_file)}")
    print(f"\n  Records: {len(df_validation):,}")
    print(f"\n  Quality Checks:")
    print(f"    Zero/Negative Distance: {(df_validation['trip_distance'] <= 0).sum()} (Expected: 0) {'✅' if (df_validation['trip_distance'] <= 0).sum() == 0 else '❌'}")
    print(f"    Negative Fare:          {(df_validation['fare_amount'] < 0).sum()} (Expected: 0) {'✅' if (df_validation['fare_amount'] < 0).sum() == 0 else '❌'}")
    print(f"    Zero Fare:              {(df_validation['fare_amount'] == 0).sum()} (Expected: 0) {'✅' if (df_validation['fare_amount'] == 0).sum() == 0 else '❌'}")
    print(f"    Invalid Passengers:     {(df_validation['passenger_count'] <= 0).sum()} (Expected: 0) {'✅' if (df_validation['passenger_count'] <= 0).sum() == 0 else '❌'}")
    
    print(f"\n  Sample Data (First 5 rows):")
    print(df_validation[['tpep_pickup_datetime', 'trip_distance', 'fare_amount', 'total_amount', 'passenger_count']].head())
    
    print("\n✅ Validation passed! Cleaned data is ready for analysis.")
else:
    print("\n❌ No cleaned files found for validation.")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# 🔍 VALIDATION CHECK
# ================================================================================
#
# ✓ Validating: yellow_tripdata_2022-10.parquet
#
#   Records: 3,395,481
#
#   Quality Checks:
#     Zero/Negative Distance: 0 (Expected: 0) ✅
#     Negative Fare:          0 (Expected: 0) ✅
#     Zero Fare:              0 (Expected: 0) ✅
#     Invalid Passengers:     0 (Expected: 0) ✅
#
#   Sample Data (First 5 rows):
#   tpep_pickup_datetime  trip_distance  fare_amount  total_amount  \
# 0  2022-10-01 00:03:41           1.70          9.5         15.95
# 1  2022-10-01 00:14:30           0.72          5.5          9.30
# 2  2022-10-01 00:27:13           1.74          9.0         12.36
# 3  2022-10-01 00:22:52           6.80         25.5         29.30
# 4  2022-10-01 00:33:19           1.88         10.5         14.30
#
#    passenger_count
# 0              1.0
# 1              2.0
# 2              1.0
# 3              1.0
# 4              3.0
#
# ✅ Validation passed! Cleaned data is ready for analysis.
#
# ================================================================================
